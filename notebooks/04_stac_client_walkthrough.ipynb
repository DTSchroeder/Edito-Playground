# %% [markdown]
# # STAC Client Walkthrough
#
# This notebook mirrors the usage patterns from the [PySTAC Client documentation](https://pystac-client.readthedocs.io/en/stable/) against the EDITO data lake. It shows how to open a catalog, traverse links, and query items programmatically.

# %% [markdown]
# ## Prerequisites
# - Activate the project virtual environment (`source .venv/bin/activate.fish`).
# - Install `pystac-client` (already listed in `requirements.txt`).
# - Export `EDITO_API_TOKEN` or `EDITO_ACCESS_TOKEN`, or drop a fallback token into `MANUAL_TOKEN` below.

# %%
# If you are running this notebook standalone, uncomment the next line
# %pip install -q -r "../requirements.txt"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
from collections import deque
from typing import Dict, List, Optional

import pandas as pd
from dotenv import load_dotenv
from pystac import STACError
from pystac_client import Client
from pystac_client.exceptions import APIError, ParametersError

# %%
load_dotenv()

API_BASE = os.getenv("EDITO_DATA_BASE_URL", "https://api.dive.edito.eu/data").rstrip("/")

TOKEN = (
    os.getenv("EDITO_API_TOKEN")
    or os.getenv("EDITO_ACCESS_TOKEN")
    or MANUAL_TOKEN
)
TOKEN_SOURCE = (
    "EDITO_API_TOKEN"
    if os.getenv("EDITO_API_TOKEN")
    else "EDITO_ACCESS_TOKEN"
    if os.getenv("EDITO_ACCESS_TOKEN")
    else "MANUAL_TOKEN"
)

if not TOKEN:
    raise RuntimeError(
        "No EDITO token detected. Export EDITO_API_TOKEN / EDITO_ACCESS_TOKEN "
        "or set MANUAL_TOKEN in your environment before running this notebook."
    )

if TOKEN_SOURCE == "MANUAL_TOKEN":
    print("⚠️ Using MANUAL_TOKEN baked into the notebook; refresh it if you encounter 401s.")

auth_headers = {"Authorization": f"Bearer {TOKEN}"}
stac_root = API_BASE
client = Client.open(stac_root, headers=auth_headers)
client
# Out:
# <Client id=root>

# %% [markdown]
# ## Inspect the catalog hierarchy
# The tutorial explores how STAC catalogs relate to one another. The code below lists the immediate `child` links exposed by the EDITO root.

# %% [markdown]
# > ℹ️ PySTAC only forwards the headers you provide to the underlying STAC API[^1], so expired or missing bearer tokens propagate as `401 Unauthorized`. Make sure you refresh EDITO tokens before opening the client.
# >
# > [^1]: See “Working with APIs” in the [PySTAC documentation](https://pystac.readthedocs.io/en/stable/api.html#pystac-client) for details about the `headers` argument.

# %%
root_children = [
    {
        "title": link.title,
        "rel": link.rel,
        "href": link.href,
    }
    for link in client.get_links("child")
]
pd.set_option("display.max_colwidth", None)
pd.DataFrame(root_children)
# Out:
#          title    rel                                        href
# 0  Collections  child  https://api.dive.edito.eu/data/collections
# 1     Catalogs  child     https://api.dive.edito.eu/data/catalogs

# %% [markdown]
# ### Explore the full catalog hierarchy
# Walk breadth-first through every nested catalog so you can see how providers are organized. Adjust `EDITO_CATALOG_DEPTH` in your environment if you want to crawl deeper than the default.

# %%
MAX_CATALOG_DEPTH = int(os.getenv("EDITO_CATALOG_DEPTH", "1"))


def _link_target_id(link) -> Optional[str]:
    target_id = getattr(link, "target_id", None)
    if target_id:
        return target_id
    extra_fields = getattr(link, "extra_fields", None)
    if isinstance(extra_fields, dict):
        return extra_fields.get("title") or extra_fields.get("href")
    return link.title or link.href


def crawl_catalog_hierarchy(root_client: Client, max_depth: int = MAX_CATALOG_DEPTH) -> pd.DataFrame:
    """Breadth-first traversal of catalog child links up to the requested depth."""
    queue = deque([(root_client, 0, None)])
    seen_hrefs = set()
    rows: List[Dict] = []

    while queue:
        current_client, depth, parent_id = queue.popleft()
        self_href = getattr(current_client, "href", None)
        if not self_href and hasattr(current_client, "get_self_href"):
            self_href = current_client.get_self_href()

        if self_href in seen_hrefs:
            continue
        if self_href:
            seen_hrefs.add(self_href)

        child_links = list(current_client.get_links("child"))
        rows.append(
            {
                "depth": depth,
                "id": getattr(current_client, "id", None),
                "title": getattr(current_client, "title", None),
                "parent_id": parent_id,
                "child_count": len(child_links),
                "href": self_href,
            }
        )

        if depth >= max_depth:
            continue

        for link in child_links:
            link_id = _link_target_id(link)
            try:
                child_client = Client.open(link.href, headers=auth_headers)
                queue.append((child_client, depth + 1, getattr(current_client, "id", None)))
            except (APIError, ParametersError, STACError, Exception) as exc:
                rows.append(
                    {
                        "depth": depth + 1,
                        "id": link_id,
                        "title": link.title,
                        "parent_id": getattr(current_client, "id", None),
                        "child_count": None,
                        "href": link.href,
                        "error": str(exc),
                    }
                )

    hierarchy_df = pd.DataFrame(rows)
    if not hierarchy_df.empty:
        hierarchy_df = hierarchy_df.sort_values(["depth", "id"], na_position="last").reset_index(drop=True)
    return hierarchy_df

catalog_hierarchy_df = crawl_catalog_hierarchy(client)
catalog_hierarchy_df
# Out:
#    depth           id               title parent_id  child_count  \
# 0      0         root  EDITO Data Catalog      None            2
# 1      1     catalogs            Catalogs      root           23
# 2      1  collections         Collections      root          442
#
#                                          href
# 0              https://api.dive.edito.eu/data
# 1     https://api.dive.edito.eu/data/catalogs
# 2  https://api.dive.edito.eu/data/collections

# %% [markdown]
# ## Enumerate collections via `Client.get_collections`
# The PySTAC Client docs highlight `client.get_collections()` for retrieving collection metadata lazily. Convert the generator to a DataFrame so it is easy to scan provider details.

# %%
collections = list(client.get_collections())
collections_df = pd.DataFrame(
    [
        {
            "id": collection.id,
            "title": collection.title,
            "license": collection.license,
            "providers": ", ".join(provider.name for provider in collection.providers or []),
        }
        for collection in collections
    ]
)
with pd.option_context("display.max_rows", None, "display.max_colwidth", None):
    display(collections_df)
# Out:
#                                                                                                                                                      id  \
# 0                                                    emodnet-3d_habitat_suitability_maps_of_the_30_main_commercial_fish_species_from_the_atlantic_ocean
# 1                                                                                            emodnet-additional_information_coastal_vulnerability_index
# 2                                                                       emodnet-additional_information_coastal_vulnerability_index_of_closest_coastline
# 3                                                                                                                       climate_forecast-age_of_sea_ice
# 4                                                                                                                          emodnet-aggregate_extraction
# 5                                                                                                               climate_forecast-aggregate_quality_flag
# 6                                                                                                                          climate_forecast-air_density
# 7                                                                                                                         climate_forecast-air_pressure
# 8                                                                                                       climate_forecast-air_pressure_at_mean_sea_level
# 9                                                                                                                      climate_forecast-air_temperature
# 10                                                                                                                             emodnet-algae_production
# 11                                                                                                                      emodnet-annex_i_habitat_subtype
# 12                                                                                                                                 emodnet-antifoulants
# 13                                                                                                                                  emodnet-aquaculture
# 14                                                                                 emodnet-areas_of_fluid_emissions_occurrence_no_occurrence_or_no_data
# 15                                                                                      emodnet-areas_of_landslides_occurrence_no_occurrence_or_no_data
# 16                                                                               emodnet-areas_of_tectonic_elements_occurrence_no_occurrence_or_no_data
# 17                                                                                        emodnet-areas_of_tsunamis_occurrence_no_occurrence_or_no_data
# 18                                                                             emodnet-areas_of_volcanic_structures_occurrence_no_occurrence_or_no_data
# 19                                                                                                                                     emodnet-areatype
# 20                                                                                                climate_forecast-atmosphere_upward_relative_vorticity
# 21                                                                                 emodnet-average_coastal_vulnerability_index_of_aggregated_coastlines
# 22                                                                                           emodnet-average_daily_ice_concentration_observation_values
# 23                                                    emodnet-average_diffuse_attenuation_coefficient_of_photosynthetic_active_radiation_kdpar_metres_1
# 24                                                                                     emodnet-average_oxygen_density_at_the_seabottom_in_the_black_sea
# 25                                                                                              climate_forecast-barotropic_eastward_sea_water_velocity
# 26                                                                                             climate_forecast-barotropic_northward_sea_water_velocity
# 27                                                                                                                                   emodnet-bathymetry
# 28                                                                                                                      emodnet-bathymetry_data_quality
# 29                                                                                                                   emodnet-bathymetry_source_metadata
# 30                                                                                                                        emodnet-bathymetry_topography
# 31                                                                                                                            emodnet-beach_litter_maps
# 32                                                                                                                 climate_forecast-beaufort_wind_force
# 33                                                                                                   emodnet-benthic_invertebrate_biomass_and_diversity
# 34                                                                                                                      emodnet-biogenic_substrate_type
# 35                                                                                                                              emodnet-biological_zone
# 36                                                                                                                                      emodnet-biology
# 37                                                                                                                     emodnet-broad_scale_habitat_maps
# 38                                                                                                                                       emodnet-cables
# 39                                                                                       emodnet-calanus_helgolandicus_and_finmarchicus_temporal_change
# 40                                                                                                                emodnet-certainty_in_habitat_presence
# 41                                                               climate_forecast-charnock_coefficient_for_surface_roughness_length_for_momentum_in_air
# 42                                                                                                                                    emodnet-chemistry
# 43                                                                                                                            emodnet-coastal_behaviour
# 44                                                                                                                  emodnet-coastal_vulnerability_index
# 45                                                                                                                                   emodnet-coastlines
# 46                                                                                                              emodnet-collection_of_classified_points
# 47                                                                                       emodnet-combined_current_and_wave_induced_energy_at_the_seabed
# 48                                                                  emodnet-community_temperature_index_cti_for_intertidal_macroalgae_in_nw_spain_deg_c
# 49                                                                                                                      emodnet-composite_data_products
# 50                                                                                                emodnet-composition_of_habitats_within_polygon_groups
# 51   climate_forecast-concentration_of_colored_dissolved_organic_matter_in_sea_water_expressed_as_equivalent_mass_fraction_of_quinine_sulfate_dihydrate
# 52                                                                                               emodnet-concentration_of_suspended_matter_in_sea_water
# 53                                                                             emodnet-confidence_in_kinetic_energy_at_the_seabed_due_to_ocean_currents
# 54                                                                      emodnet-confidence_in_kinetic_energy_values_at_the_seabed_due_to_ocean_currents
# 55                                                                               emodnet-confidence_in_kinetic_energy_values_at_the_seabed_due_to_waves
# 56                                                                         emodnet-confidence_in_the_presence_and_or_extent_of_the_annex_i_habitat_type
# 57                                                                                                                            emodnet-contaminants_maps
# 58                                                                                                emodnet-count_maps_of_sea_birds_in_the_europeans_seas
# 59                                                                                                                            emodnet-cultural_heritage
# 60                                                                                                                      emodnet-dataset_identifier_code
# 61                                                                            emodnet-date_when_the_habitat_was_determined_to_be_a_mangrove_eov_habitat
# 62                                                                                                   emodnet-deepest_values_of_water_body_chlorophyll_a
# 63                                                                                                        emodnet-deepest_values_of_water_body_silicate
# 64                                                                                    emodnet-degree_of_suitability_for_the_essential_fish_habitat_area
# 65                                                                                                                                 emodnet-desalination
# 66                                                                                                               climate_forecast-dew_point_temperature
# 67                                                                                                                  climate_forecast-divergence_of_wind
# 68                                                                                 climate_forecast-downwelling_photosynthetic_photon_flux_in_sea_water
# 69                                                                                                                                     emodnet-dredging
# 70                                                                                                                                                EDITO
# 71                                                                                                                         emodnet-earthquake_magnitude
# 72                                                                                                                                  emodnet-earthquakes
# 73                                                                                                           climate_forecast-eastward_sea_ice_velocity
# 74                                                                                                         climate_forecast-eastward_sea_water_velocity
# 75                                                                                        climate_forecast-eastward_sea_water_velocity_assuming_no_tide
# 76                                                                                      climate_forecast-eastward_sea_water_velocity_due_to_ekman_drift
# 77                                                                                                                       climate_forecast-eastward_wind
# 78                                                                                                                                    emodnet-elevation
# 79                                                                                                                                       emodnet-energy
# 80                                                                                                                                  emodnet-environment
# 81                                                                                                                       emodnet-eov_determination_date
# 82                                                                                     emodnet-essential_fish_habitat_nursery_grounds_map_aphia_id_code
# 83                                                                                                                  emodnet-essential_fish_habitat_type
# 84                                                                                                             emodnet-essential_ocean_variable_subtype
# 85                                                                                                                emodnet-essential_ocean_variable_type
# 86                                                                                                                   emodnet-eunis_2007_11_habitat_code
# 87                                                                                                                      emodnet-eunis_2022_habitat_code
# 88                                                                                                            emodnet-eunis_2022_level_2_classification
# 89                                                                                                           emodnet-eunis_version_2007_11_habitat_code
# 90                                                                                                                      emodnet-euseamap_classification
# 91                                                                                                             emodnet-eutrophication_interpolated_maps
# 92                                                                                              emodnet-eutrophication_maps_of_depth_and_density_layers
# 93                                                                                                                  emodnet-fertilisers_and_chlorophyll
# 94                                                                                                emodnet-fish_catches_by_fao_areas_and_commodity_group
# 95                                                                                                                                  emodnet-fish_quotas
# 96                                                                                                                                    emodnet-fisheries
# 97                                                                                                                  emodnet-fisheries_fishing_intensity
# 98                                                                                        emodnet-fishing_effort_by_fao_areas_gfcm_subareas_and_country
# 99                                                                                                                              emodnet-fluid_emissions
# 100                                                                                       climate_forecast-fractional_saturation_of_oxygen_in_sea_water
# 101                                                                                            climate_forecast-fugacity_of_carbon_dioxide_in_sea_water
# 102                                                                                                               emodnet-geological_event_distribution
# 103                                                                                                                                     emodnet-geology
# 104                                                                                                                               emodnet-geomorphology
# 105                                                                                                                         emodnet-geomorphology_lines
# 106                                                                                                                climate_forecast-geopotential_height
# 107                                                                                            climate_forecast-geostrophic_eastward_sea_water_velocity
# 108                                                                                           climate_forecast-geostrophic_northward_sea_water_velocity
# 109                                                                                             climate_forecast-global_average_steric_sea_level_change
# 110                                                                            emodnet-global_predicted_thermal_distributions_for_intertidal_macroalgae
# 111                                                                                        emodnet-habitat_classification_that_describes_salinity_level
# 112                                                             emodnet-habitat_maps_in_the_helcom_underwater_biotope_and_habitat_classification_system
# 113                                    emodnet-habitat_maps_in_the_marine_strategy_framework_directive_benthic_broad_habitat_type_classification_system
# 114                                                                                emodnet-habitat_suitability_of_reef_forming_species_in_the_north_sea
# 115                                                                                                     emodnet-habitats_directive_annex_i_habitat_code
# 116                                                                                                                                emodnet-heavy_metals
# 117                                                                                                           emodnet-helcom_hub_classification_habitat
# 118                                                                    emodnet-helcom_underwater_biotope_and_habitat_classification_system_habitat_code
# 119                                                                                                                                  emodnet-horizontal
# 120                                                                                                                            emodnet-human_activities
# 121                                                                                                                            emodnet-hydrocarbons_pah
# 122                                                                                                                            emodnet-ice_concentation
# 123                                                                                emodnet-individual_habitat_maps_from_surveys_essential_fish_habitats
# 124                                                                    emodnet-individual_habitat_maps_from_surveys_seabed_and_coastal_wetland_habitats
# 125                                                                                                       emodnet-kinetic_energy_at_seabed_due_to_waves
# 126                                                                                                emodnet-kinetic_energy_at_the_seabed_due_to_currents
# 127                                                                                                                emodnet-landslide_susceptibility_map
# 128                                                                                                                           climate_forecast-latitude
# 129                                                                                                                   emodnet-length_of_landslide_scarp
# 130                                                                                                                                       emodnet-level
# 131                                                                                                                                       emodnet-light
# 132                                                                                                 emodnet-loggerhead_turtles_in_the_mediterranean_sea
# 133                                                                                                                          climate_forecast-longitude
# 134                                                                                                             climate_forecast-lwe_precipitation_rate
# 135                                                                                               climate_forecast-magnitude_of_surface_downward_stress
# 136                                                                                                                                  emodnet-main_ports
# 137                                                                                                           emodnet-mammal_abundance_and_distribution
# 138                                                                                                                  emodnet-mangrove_dataset_source_id
# 139                                                                                                                           emodnet-marine_aggregates
# 140                                                                                                                    emodnet-marine_critical_minerals
# 141                                                                                                             emodnet-marine_hydrocarbon_and_hydrates
# 142                                                                                                                emodnet-marine_non_critical_minerals
# 143                                                                              emodnet-marine_strategy_framework_directive_benthic_broad_habitat_type
# 144                                                                                                                   emodnet-maritime_spatial_planning
# 145                                                                                   climate_forecast-mass_concentration_of_chlorophyll_a_in_sea_water
# 146                                                                                     climate_forecast-mass_concentration_of_chlorophyll_in_sea_water
# 147                                                                climate_forecast-mass_concentration_of_diatoms_expressed_as_chlorophyll_in_sea_water
# 148                                                     climate_forecast-mass_concentration_of_microphytoplankton_expressed_as_chlorophyll_in_sea_water
# 149                                                      climate_forecast-mass_concentration_of_nanophytoplankton_expressed_as_chlorophyll_in_sea_water
# 150                                                      climate_forecast-mass_concentration_of_picophytoplankton_expressed_as_chlorophyll_in_sea_water
# 151                                                                                climate_forecast-mass_concentration_of_suspended_matter_in_sea_water
# 152                                                                           emodnet-mean_of_annual_90th_percentile_kinetic_energy_due_to_waves_values
# 153                                                           emodnet-mean_of_annual_90th_percentile_kinetic_energy_due_to_waves_values_in_the_atlantic
# 154                                             emodnet-mean_of_annual_90th_percentile_kinetic_energy_values_at_the_seabed_due_to_ocean_currents_n_s_m2
# 155                                                           emodnet-mean_of_annual_90th_percentile_kinetic_energy_values_between_2016_and_2018_n_s_m2
# 156                                                                           emodnet-mean_of_annual_90th_percentile_kinetic_energy_values_due_to_waves
# 157                                                                                 emodnet-mean_of_annual_90th_percentile_kinetic_energy_values_n_s_m2
# 158                                                                     emodnet-mean_of_annual_90th_percentile_kinetic_energy_wave_at_the_seabed_values
# 159                                                                                                               emodnet-measure_of_the_tsunami_impact
# 160                                                                                                          emodnet-measurement_time_period_field_data
# 161                                                                                                      emodnet-measurement_time_period_satellite_data
# 162                                                                                                                       emodnet-mesh_confidence_score
# 163                                                                                                                           emodnet-micro_litter_maps
# 164                                                                                                                               emodnet-microplastics
# 165                                                                                                                  emodnet-migration_class_field_data
# 166                                                                                                              emodnet-migration_class_satellite_data
# 167                                                                                                                              emodnet-military_areas
# 168                                                                                                          emodnet-mixoplankton_biomass_and_diversity
# 169                           emodnet-modelled_projections_of_habitat_for_commercial_fish_around_north_western_europe_under_climate_change_2020_to_2060
# 170               emodnet-modelled_projections_of_habitat_for_fish_species_feeding_guilds_around_north_western_europe_under_climate_change_2010_to_2095
# 171                                                                                        climate_forecast-mole_concentration_of_ammonium_in_sea_water
# 172                                                                     climate_forecast-mole_concentration_of_diatoms_expressed_as_carbon_in_sea_water
# 173                                                                      climate_forecast-mole_concentration_of_dissolved_inorganic_carbon_in_sea_water
# 174                                                                                  climate_forecast-mole_concentration_of_dissolved_iron_in_sea_water
# 175                                                                      climate_forecast-mole_concentration_of_dissolved_molecular_oxygen_in_sea_water
# 176                                                                                climate_forecast-mole_concentration_of_hydrogen_sulfide_in_sea_water
# 177                                                                             climate_forecast-mole_concentration_of_nitrate_and_nitrite_in_sea_water
# 178                                                                                         climate_forecast-mole_concentration_of_nitrate_in_sea_water
# 179                                                                                         climate_forecast-mole_concentration_of_nitrite_in_sea_water
# 180                                                                                       climate_forecast-mole_concentration_of_phosphate_in_sea_water
# 181                                                               climate_forecast-mole_concentration_of_phytoplankton_expressed_as_carbon_in_sea_water
# 182                                                           climate_forecast-mole_concentration_of_picophytoplankton_expressed_as_carbon_in_sea_water
# 183                                                                                        climate_forecast-mole_concentration_of_silicate_in_sea_water
# 184                                                                 climate_forecast-mole_concentration_of_zooplankton_expressed_as_carbon_in_sea_water
# 185                                                                     climate_forecast-moles_of_dissolved_inorganic_carbon_per_unit_mass_in_sea_water
# 186                                                                                        climate_forecast-moles_of_nitrate_per_unit_mass_in_sea_water
# 187                                                                                        climate_forecast-moles_of_nitrite_per_unit_mass_in_sea_water
# 188                                                                                         climate_forecast-moles_of_oxygen_per_unit_mass_in_sea_water
# 189                                                                                      climate_forecast-moles_of_phosphate_per_unit_mass_in_sea_water
# 190                                                                                       climate_forecast-moles_of_silicate_per_unit_mass_in_sea_water
# 191                                                                                                 emodnet-morphological_and_lithological_coastal_type
# 192                                                                               emodnet-morphological_and_lithological_coastal_type_closest_coastline
# 193                                                                                                    emodnet-morphological_type_of_volcanic_structure
# 194                                                                                                                         emodnet-morphology_category
# 195                                                                                                       emodnet-morphology_category_closest_coastline
# 196                                                                                                             emodnet-msfd_benthic_broad_habitat_type
# 197                                                                                                                                        emodnet-name
# 198                                                                                   climate_forecast-net_downward_shortwave_flux_at_sea_water_surface
# 199                                                 climate_forecast-net_primary_production_of_biomass_expressed_as_carbon_per_unit_volume_in_sea_water
# 200                                                                                                         climate_forecast-northward_sea_ice_velocity
# 201                                                                                                       climate_forecast-northward_sea_water_velocity
# 202                                                                                      climate_forecast-northward_sea_water_velocity_assuming_no_tide
# 203                                                                                    climate_forecast-northward_sea_water_velocity_due_to_ekman_drift
# 204                                                                                                                     climate_forecast-northward_wind
# 205                                                                                                   climate_forecast-number_of_icebergs_per_unit_area
# 206                                                                                                             climate_forecast-number_of_observations
# 207                                                                                                                             emodnet-occurrence_data
# 208                                                                                                    climate_forecast-ocean_barotropic_streamfunction
# 209                                                                                        climate_forecast-ocean_meridional_overturning_streamfunction
# 210                                                                                                        climate_forecast-ocean_mixed_layer_thickness
# 211                                                                                 climate_forecast-ocean_mixed_layer_thickness_defined_by_sigma_theta
# 212                                                                                                 climate_forecast-ocean_volume_transport_across_line
# 213                                                                                                                                 emodnet-oil_and_gas
# 214                                                                                                                      emodnet-original_eunis_habitat
# 215                                                                                                                 emodnet-original_eunis_habitat_type
# 216                                                                                                                            emodnet-original_habitat
# 217                                                                                                      emodnet-original_habitat_classification_scheme
# 218                                                                                                                       emodnet-original_habitat_type
# 219                                                                                      emodnet-original_habitat_type_which_relate_to_the_mangrove_eov
# 220                                                                                                                      emodnet-original_ospar_habitat
# 221                                                                                                                       emodnet-ospar_habitat_subtype
# 222                                                                                                                          emodnet-ospar_habitat_type
# 223                                                                                                              emodnet-other_forms_of_area_management
# 224                                                                                                                    emodnet-other_specific_protocols
# 225                                                                                                                              emodnet-oxygen_density
# 226                                                                                                             emodnet-oxygenation_level_at_the_seabed
# 227                                                                                                                     emodnet-pesticides_and_biocides
# 228                                                                    emodnet-photosynthetic_active_radiation_par_reaching_the_seabed_mol.phot.m_2.d_1
# 229                                                                                                                                     emodnet-physics
# 230                                                                                                                      emodnet-physiographic_features
# 231                                                                                                         emodnet-phytoplankton_biomass_and_diversity
# 232                                                                                                                                   emodnet-pipelines
# 233                                                                                                              climate_forecast-platform_zenith_angle
# 234                                                                                                                       emodnet-pre_quaternary_faults
# 235                                                                                                                  emodnet-pre_quaternary_geology_age
# 236                                                                                                                    emodnet-pre_quaternary_lithology
# 237                                                                                                                 climate_forecast-precipitation_flux
# 238                                                                                                                             emodnet-protected_areas
# 239                                                                                                                                   emodnet-purposeqi
# 240                                                                                                                                  emodnet-qicombined
# 241                                                                                                                                      emodnet-qidate
# 242                                                                                                                       climate_forecast-quality_flag
# 243                                                                                                                      emodnet-quaternary_geology_age
# 244                                                                                                                emodnet-quaternary_geology_lithology
# 245                                                                                                                        emodnet-quaternary_tectonics
# 246                                                                                       emodnet-ramsar_classification_system_for_wetland_type_habitat
# 247                                                                                                        emodnet-rate_of_coastal_migration_field_data
# 248                                                                                                    emodnet-rate_of_coastal_migration_satellite_data
# 249                                                                              emodnet-relationship_between_original_habitat_and_annex_i_habitat_type
# 250                                                                emodnet-relationship_between_original_habitat_and_eunis_version_2007_11_habitat_type
# 251                                                                               emodnet-relationship_between_original_habitat_and_ramsar_habitat_type
# 252                                                                                                                  climate_forecast-relative_humidity
# 253                                                                                                          emodnet-remark_coastal_vulnerability_index
# 254                                                                                     emodnet-remark_coastal_vulnerability_index_of_closest_coastline
# 255                                                                                        emodnet-revised_classification_of_mediterranean_habitat_type
# 256                                                                                                                 emodnet-route_density_annual_totals
# 257                                                                                                                emodnet-route_density_monthly_totals
# 258                                                                                                               emodnet-route_density_seasonal_totals
# 259                                                                                                                emodnet-salinity_level_at_the_seabed
# 260                                                                                                                                 emodnet-sample_date
# 261                                                                                                                             emodnet-sampling_method
# 262                                                                                            emodnet-scientific_reference_coastal_vulnerability_index
# 263                                                                       emodnet-scientific_reference_coastal_vulnerability_index_of_closest_coastline
# 264                                                                                               climate_forecast-sea_floor_depth_below_mean_sea_level
# 265                                                                                                                     climate_forecast-sea_ice_albedo
# 266                                                                                                              climate_forecast-sea_ice_area_fraction
# 267                                                                                                             climate_forecast-sea_ice_classification
# 268                                                                                                                     climate_forecast-sea_ice_extent
# 269                                                                                                                      climate_forecast-sea_ice_speed
# 270                                                                                                        climate_forecast-sea_ice_surface_temperature
# 271                                                                                                                  climate_forecast-sea_ice_thickness
# 272                                                                                                      climate_forecast-sea_ice_transport_across_line
# 273                                                                                                                     climate_forecast-sea_ice_volume
# 274                                                                                                             climate_forecast-sea_ice_x_displacement
# 275                                                                                                                 climate_forecast-sea_ice_x_velocity
# 276                                                                                                             climate_forecast-sea_ice_y_displacement
# 277                                                                                                                 climate_forecast-sea_ice_y_velocity
# 278                                                                                                                climate_forecast-sea_surface_density
# 279                                                                                                 climate_forecast-sea_surface_foundation_temperature
# 280                                                                                                     climate_forecast-sea_surface_height_above_geoid
# 281                                                                                            climate_forecast-sea_surface_height_above_mean_sea_level
# 282                                                                                                          emodnet-sea_surface_height_above_sea_level
# 283                                                                          climate_forecast-sea_surface_height_amplitude_due_to_geocentric_ocean_tide
# 284                                                                 climate_forecast-sea_surface_height_correction_due_to_air_pressure_at_low_frequency
# 285                                                                                      climate_forecast-sea_surface_primary_swell_wave_from_direction
# 286                                                 climate_forecast-sea_surface_primary_swell_wave_from_direction_at_variance_spectral_density_maximum
# 287                                                                                         climate_forecast-sea_surface_primary_swell_wave_mean_period
# 288                                                         climate_forecast-sea_surface_primary_swell_wave_period_at_variance_spectral_density_maximum
# 289                                                                                  climate_forecast-sea_surface_primary_swell_wave_significant_height
# 290                                                                                                               climate_forecast-sea_surface_salinity
# 291                                                                                    climate_forecast-sea_surface_secondary_swell_wave_from_direction
# 292                                               climate_forecast-sea_surface_secondary_swell_wave_from_direction_at_variance_spectral_density_maximum
# 293                                                                                       climate_forecast-sea_surface_secondary_swell_wave_mean_period
# 294                                                       climate_forecast-sea_surface_secondary_swell_wave_period_at_variance_spectral_density_maximum
# 295                                                                                climate_forecast-sea_surface_secondary_swell_wave_significant_height
# 296                                                                                                    climate_forecast-sea_surface_subskin_temperature
# 297                                                                                                            climate_forecast-sea_surface_temperature
# 298                                                climate_forecast-sea_surface_tertiary_swell_wave_from_direction_at_variance_spectral_density_maximum
# 299                                                        climate_forecast-sea_surface_tertiary_swell_wave_period_at_variance_spectral_density_maximum
# 300                                                                                 climate_forecast-sea_surface_tertiary_swell_wave_significant_height
# 301                                                           climate_forecast-sea_surface_wave_directional_spread_at_variance_spectral_density_maximum
# 302                                                                       climate_forecast-sea_surface_wave_energy_at_variance_spectral_density_maximum
# 303                                                                                                    climate_forecast-sea_surface_wave_from_direction
# 304                                                               climate_forecast-sea_surface_wave_from_direction_at_variance_spectral_density_maximum
# 305                                                                                              climate_forecast-sea_surface_wave_maximum_crest_height
# 306                                                                                                    climate_forecast-sea_surface_wave_maximum_height
# 307                                                                                                    climate_forecast-sea_surface_wave_maximum_period
# ...
# 421                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      EMODnet Chemistry
# 422                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      EMODnet Chemistry
# 423                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      EMODnet Chemistry
# 424                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      EMODnet Chemistry
# 425                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                EMODnet Seabed Habitats
# 426                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 427                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 428                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 429                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 430                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                EMODnet Seabed Habitats
# 431                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                EMODnet Seabed Habitats
# 432                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 433                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               EMODnet Human Activities
# 434                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               EMODnet Human Activities
# 435                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               EMODnet Human Activities
# 436                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 437                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 438                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 439                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 440                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  EDITO
# 441                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                EMODnet Biology, ULiege

# %% [markdown]
# ## Inspect a specific collection
# Inspired by the CDSE example notebook, parameterize the collection ID you want to study and materialize its metadata so you can understand the spatial/temporal extents before querying items.

# %%
SPECIFIC_COLLECTION_ID = os.getenv("EDITO_SPECIFIC_COLLECTION", "SENTINEL1_EW_GRDM_1SDH")
specific_collection = next(
    (collection for collection in collections if collection.id == SPECIFIC_COLLECTION_ID),
    None,
)
if specific_collection is None:
    available_ids = sorted(collection.id for collection in collections[:20])
    raise ValueError(
        f"Collection {SPECIFIC_COLLECTION_ID} not found in the cached catalog list. "
        f"Set EDITO_SPECIFIC_COLLECTION to one of the available IDs (sample: {available_ids})."
    )

collection_summary = specific_collection.to_dict().get("summaries", {})
collection_row = {
    "id": specific_collection.id,
    "title": specific_collection.title,
    "license": specific_collection.license,
    "providers": ", ".join(provider.name for provider in specific_collection.providers or []),
    "spatial_extent": specific_collection.extent.spatial.bboxes if specific_collection.extent else None,
    "temporal_extent": specific_collection.extent.temporal.intervals if specific_collection.extent else None,
    "platform": collection_summary.get("platform"),
}
pd.DataFrame([collection_row])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       6 if specific_collection is None:
#       7     available_ids = sorted(collection.id for collection in collections[:20])
# ----> 8     raise ValueError(
#       9         f"Collection {SPECIFIC_COLLECTION_ID} not found in the cached catalog list. "
#      10         f"Set EDITO_SPECIFIC_COLLECTION to one of the available IDs (sample: {available_ids})."
#      11     )
#      13 collection_summary = specific_collection.to_dict().get("summaries", {})
#      14 collection_row = {
#      15     "id": specific_collection.id,
#      16     "title": specific_collection.title,
#    (...)     21     "platform": collection_summary.get("platform"),
#      22 }
#
# ValueError: Collection SENTINEL1_EW_GRDM_1SDH not found in the cached catalog list. Set EDITO_SPECIFIC_COLLECTION to one of the available IDs (sample: ['climate_forecast-age_of_sea_ice', 'climate_forecast-aggregate_quality_flag', 'climate_forecast-air_density', 'climate_forecast-air_pressure', 'climate_forecast-air_pressure_at_mean_sea_level', 'climate_forecast-air_temperature', 'emodnet-3d_habitat_suitability_maps_of_the_30_main_commercial_fish_species_from_the_atlantic_ocean', 'emodnet-additional_information_coastal_vulnerability_index', 'emodnet-additional_information_coastal_vulnerability_index_of_closest_coastline', 'emodnet-aggregate_extraction', 'emodnet-algae_production', 'emodnet-annex_i_habitat_subtype', 'emodnet-antifoulants', 'emodnet-aquaculture', 'emodnet-areas_of_fluid_emissions_occurrence_no_occurrence_or_no_data', 'emodnet-areas_of_landslides_occurrence_no_occurrence_or_no_data', 'emodnet-areas_of_tectonic_elements_occurrence_no_occurrence_or_no_data', 'emodnet-areas_of_tsunamis_occurrence_no_occurrence_or_no_data', 'emodnet-areas_of_volcanic_structures_occurrence_no_occurrence_or_no_data', 'emodnet-areatype']).

# %% [markdown]
# ### Search the collection with CDSE-style filters
# Mirror the CDSE example by running a spatial/temporal search against the chosen collection. Adjust the bounding box or time range if your area of interest differs.

# %%
COLLECTION_SEARCH_BBOX = [-10.0, 50.0, 5.0, 60.0]
COLLECTION_SEARCH_DATETIME = "2024-01-01/2024-01-10"
COLLECTION_SEARCH_LIMIT = 5

specific_search = client.search(
    collections=[SPECIFIC_COLLECTION_ID],
    bbox=COLLECTION_SEARCH_BBOX,
    datetime=COLLECTION_SEARCH_DATETIME,
    max_items=COLLECTION_SEARCH_LIMIT,
)
specific_items = list(specific_search.get_items())
if not specific_items:
    raise ValueError(
        "No items returned for the specified collection/bbox/datetime; adjust the filters and retry."
    )

specific_item_rows: List[Dict] = []
for item in specific_items:
    props = item.to_dict().get("properties", {})
    specific_item_rows.append(
        {
            "id": item.id,
            "datetime": props.get("datetime"),
            "bbox": item.bbox,
            "asset_count": len(item.assets or {}),
        }
    )
pd.DataFrame(specific_item_rows)
# Out:
# /Users/daniels/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[13], line 11
#       3 COLLECTION_SEARCH_LIMIT = 5
#       5 specific_search = client.search(
#       6     collections=[SPECIFIC_COLLECTION_ID],
#       7     bbox=COLLECTION_SEARCH_BBOX,
#       8     datetime=COLLECTION_SEARCH_DATETIME,
#       9     max_items=COLLECTION_SEARCH_LIMIT,
#      10 )
# ---> 11 specific_items = list(specific_search.get_items())
#      12 if not specific_items:
#      13     raise ValueError(
#      14         "No items returned for the specified collection/bbox/datetime; adjust the filters and retry."
#      15     )
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:785, in ItemSearch.items(self)
#     778 def items(self) -> Iterator[Item]:
#     779     """Iterator that yields :class:`pystac.Item` instances for each item matching
#     780     the given search parameters.
#     781
#     782     Yields:
#     783         Item : each Item matching the search criteria
#     784     """
# --> 785     for item in self.items_as_dicts():
#     786         # already signed in items_as_dicts
#     787         yield Item.from_dict(item, root=self.client, preserve_dict=False)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:796, in ItemSearch.items_as_dicts(self)
#     789 def items_as_dicts(self) -> Iterator[dict[str, Any]]:
#     790     """Iterator that yields :class:`dict` instances for each item matching
#     791     the given search parameters.
#     792
#     793     Yields:
#     794         Item : each Item matching the search criteria
#     795     """
# --> 796     for page in self.pages_as_dicts():
#     797         yield from page.get("features", [])
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:826, in ItemSearch.pages_as_dicts(self)
#     824 if isinstance(self._stac_io, StacApiIO):
#     825     num_items = 0
# --> 826     for page in self._stac_io.get_pages(
#     827         self.url, self.method, self.get_parameters()
#     828     ):
#     829         call_modifier(self.modifier, page)
#     830         features = page.get("features", [])
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:304, in StacApiIO.get_pages(self, url, method, parameters)
#     292 def get_pages(
#     293     self,
#     294     url: str,
#     295     method: str | None = None,
#     296     parameters: dict[str, Any] | None = None,
#     297 ) -> Iterator[dict[str, Any]]:
#     298     """Iterator that yields dictionaries for each page at a STAC paging
#     299     endpoint, e.g., /collections, /search
#     300
#     301     Return:
#     302         Dict[str, Any] : JSON content from a single page
#     303     """
# --> 304     page = self.read_json(url, method=method, parameters=parameters)
#     305     if not (page.get("features") or page.get("collections")):
#     306         return None
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac/stac_io.py:206, in StacIO.read_json(self, source, *args, **kwargs)
#     189 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> dict[str, Any]:
#     190     """Read a dict from the given source.
#     191
#     192     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)    204         given source.
#     205     """
# --> 206     txt = self.read_text(source, *args, **kwargs)
#     207     return self.json_loads(txt)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:167, in StacApiIO.read_text(self, source, *args, **kwargs)
#     165 href = str(source)
#     166 if _is_url(href):
# --> 167     return self.request(href, *args, **kwargs)
#     168 else:
#     169     with open(href) as f:
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:219, in StacApiIO.request(self, href, method, headers, parameters)
#     217     raise APIError(str(err))
#     218 if resp.status_code != 200:
# --> 219     raise APIError.from_response(resp)
#     220 try:
#     221     return resp.content.decode("utf-8")
#
# APIError: {"ErrorMessage":"Not Found","ErrorCode":404}

# %% [markdown]
# ## Open a provider catalog and inspect collections
# Pick any catalog from above (for example `copernicus-marine-products`) and fetch its `collection` links.

# %%
TARGET_CATALOG_HREF = f"{API_BASE}/catalogs/copernicus-marine-products"
provider_client = Client.open(TARGET_CATALOG_HREF, headers=auth_headers)
collection_links = [
    {
        "id": link.target_id,
        "title": link.title,
        "href": link.href,
    }
    for link in provider_client.get_links("collection")
]
pd.DataFrame(collection_links).head(10)
# Out:
# /Users/daniels/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/client.py:191: NoConformsTo: Server does not advertise any conformance classes.
#   warnings.warn(NoConformsTo())
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Search for CMEMS items
# The tutorial demonstrates `Client.search` for filtering items. Here we look up the requested CMEMS collection IDs.

# %%
TARGET_COLLECTION = "NWSHELF_ANALYSISFORECAST_PHY_004_013"
search = client.search(collections=[TARGET_COLLECTION], max_items=10)
items = list(search.get_items())
if not items:
    raise ValueError("No items returned; try a different collection or relax filters.")

item_rows: List[Dict] = []
for item in items:
    props = item.to_dict().get("properties", {})
    item_rows.append(
        {
            "id": item.id,
            "collection": item.collection_id,
            "datetime": props.get("datetime"),
            "asset_keys": list(item.assets.keys()),
        }
    )
pd.DataFrame(item_rows)
# Out:
# /Users/daniels/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 TARGET_COLLECTION = "NWSHELF_ANALYSISFORECAST_PHY_004_013"
#       2 search = client.search(collections=[TARGET_COLLECTION], max_items=10)
# ----> 3 items = list(search.get_items())
#       4 if not items:
#       5     raise ValueError("No items returned; try a different collection or relax filters.")
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:785, in ItemSearch.items(self)
#     778 def items(self) -> Iterator[Item]:
#     779     """Iterator that yields :class:`pystac.Item` instances for each item matching
#     780     the given search parameters.
#     781
#     782     Yields:
#     783         Item : each Item matching the search criteria
#     784     """
# --> 785     for item in self.items_as_dicts():
#     786         # already signed in items_as_dicts
#     787         yield Item.from_dict(item, root=self.client, preserve_dict=False)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:796, in ItemSearch.items_as_dicts(self)
#     789 def items_as_dicts(self) -> Iterator[dict[str, Any]]:
#     790     """Iterator that yields :class:`dict` instances for each item matching
#     791     the given search parameters.
#     792
#     793     Yields:
#     794         Item : each Item matching the search criteria
#     795     """
# --> 796     for page in self.pages_as_dicts():
#     797         yield from page.get("features", [])
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:826, in ItemSearch.pages_as_dicts(self)
#     824 if isinstance(self._stac_io, StacApiIO):
#     825     num_items = 0
# --> 826     for page in self._stac_io.get_pages(
#     827         self.url, self.method, self.get_parameters()
#     828     ):
#     829         call_modifier(self.modifier, page)
#     830         features = page.get("features", [])
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:304, in StacApiIO.get_pages(self, url, method, parameters)
#     292 def get_pages(
#     293     self,
#     294     url: str,
#     295     method: str | None = None,
#     296     parameters: dict[str, Any] | None = None,
#     297 ) -> Iterator[dict[str, Any]]:
#     298     """Iterator that yields dictionaries for each page at a STAC paging
#     299     endpoint, e.g., /collections, /search
#     300
#     301     Return:
#     302         Dict[str, Any] : JSON content from a single page
#     303     """
# --> 304     page = self.read_json(url, method=method, parameters=parameters)
#     305     if not (page.get("features") or page.get("collections")):
#     306         return None
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac/stac_io.py:206, in StacIO.read_json(self, source, *args, **kwargs)
#     189 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> dict[str, Any]:
#     190     """Read a dict from the given source.
#     191
#     192     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)    204         given source.
#     205     """
# --> 206     txt = self.read_text(source, *args, **kwargs)
#     207     return self.json_loads(txt)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:167, in StacApiIO.read_text(self, source, *args, **kwargs)
#     165 href = str(source)
#     166 if _is_url(href):
# --> 167     return self.request(href, *args, **kwargs)
#     168 else:
#     169     with open(href) as f:
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:219, in StacApiIO.request(self, href, method, headers, parameters)
#     217     raise APIError(str(err))
#     218 if resp.status_code != 200:
# --> 219     raise APIError.from_response(resp)
#     220 try:
#     221     return resp.content.decode("utf-8")
#
# APIError: {"ErrorMessage":"Not Found","ErrorCode":404}

# %% [markdown]
# ### ItemCollection summary
# Per the PySTAC Client guide, materialize the full STAC `ItemCollection` to inspect counts and aggregate metadata for the current search result.

# %%
item_collection = search.item_collection()
item_collection_dict = item_collection.to_dict()
summary = {
    "returned_features": len(item_collection_dict.get("features", [])),
    "matched": item_collection_dict.get("numberMatched"),
    "returned": item_collection_dict.get("numberReturned"),
    "bbox": item_collection_dict.get("bbox"),
}
pd.DataFrame([summary])
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 item_collection = search.item_collection()
#       2 item_collection_dict = item_collection.to_dict()
#       3 summary = {
#       4     "returned_features": len(item_collection_dict.get("features", [])),
#       5     "matched": item_collection_dict.get("numberMatched"),
#       6     "returned": item_collection_dict.get("numberReturned"),
#       7     "bbox": item_collection_dict.get("bbox"),
#       8 }
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:855, in ItemSearch.item_collection(self)
#     847 """
#     848 Get the matching items as a :py:class:`pystac.ItemCollection`.
#     849
#     850 Return:
#     851     ItemCollection: The item collection
#     852 """
#     853 # Bypass the cache here, so that we can pass __preserve_dict__
#     854 # without mutating what's in the cache.
# --> 855 feature_collection = self.item_collection_as_dict.__wrapped__(self)
#     856 # already signed in item_collection_as_dict
#     857 return ItemCollection.from_dict(
#     858     feature_collection, preserve_dict=False, root=self.client
#     859 )
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:876, in ItemSearch.item_collection_as_dict(self)
#     863 """
#     864 Get the matching items as an item-collection-like dict.
#     865
#    (...)    873     Dict : A GeoJSON FeatureCollection
#     874 """
#     875 features = []
# --> 876 for page in self.pages_as_dicts():
#     877     for feature in page["features"]:
#     878         features.append(feature)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/item_search.py:826, in ItemSearch.pages_as_dicts(self)
#     824 if isinstance(self._stac_io, StacApiIO):
#     825     num_items = 0
# --> 826     for page in self._stac_io.get_pages(
#     827         self.url, self.method, self.get_parameters()
#     828     ):
#     829         call_modifier(self.modifier, page)
#     830         features = page.get("features", [])
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:304, in StacApiIO.get_pages(self, url, method, parameters)
#     292 def get_pages(
#     293     self,
#     294     url: str,
#     295     method: str | None = None,
#     296     parameters: dict[str, Any] | None = None,
#     297 ) -> Iterator[dict[str, Any]]:
#     298     """Iterator that yields dictionaries for each page at a STAC paging
#     299     endpoint, e.g., /collections, /search
#     300
#     301     Return:
#     302         Dict[str, Any] : JSON content from a single page
#     303     """
# --> 304     page = self.read_json(url, method=method, parameters=parameters)
#     305     if not (page.get("features") or page.get("collections")):
#     306         return None
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac/stac_io.py:206, in StacIO.read_json(self, source, *args, **kwargs)
#     189 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> dict[str, Any]:
#     190     """Read a dict from the given source.
#     191
#     192     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)    204         given source.
#     205     """
# --> 206     txt = self.read_text(source, *args, **kwargs)
#     207     return self.json_loads(txt)
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:167, in StacApiIO.read_text(self, source, *args, **kwargs)
#     165 href = str(source)
#     166 if _is_url(href):
# --> 167     return self.request(href, *args, **kwargs)
#     168 else:
#     169     with open(href) as f:
#
# File ~/Mono/projects/work/sintef/Edito-Playground/.venv/lib/python3.13/site-packages/pystac_client/stac_api_io.py:219, in StacApiIO.request(self, href, method, headers, parameters)
#     217     raise APIError(str(err))
#     218 if resp.status_code != 200:
# --> 219     raise APIError.from_response(resp)
#     220 try:
#     221     return resp.content.decode("utf-8")
#
# APIError: {"ErrorMessage":"Not Found","ErrorCode":404}

# %% [markdown]
# ## Inspect assets from the first item
# Mimicking the tutorial, expose the available assets, media types, and roles so you can decide what to download next.

# %%
first_item = items[0]
assets_df = pd.DataFrame(
    [
        {
            "asset_key": key,
            "roles": asset.roles,
            "media_type": asset.media_type,
            "href": asset.href,
        }
        for key, asset in first_item.assets.items()
    ]
)
assets_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 first_item = items[0]
#       2 assets_df = pd.DataFrame(
#       3     [
#       4         {
#    (...)     11     ]
#      12 )
#      13 assets_df
#
# NameError: name 'items' is not defined

# %% [markdown]
# ## Preview the full STAC item JSON
# Use this when you need to inspect geometry, providers, or asset metadata in detail.

# %%
print(json.dumps(first_item.to_dict(), indent=2)[:2000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(json.dumps(first_item.to_dict(), indent=2)[:2000])
#
# NameError: name 'first_item' is not defined
